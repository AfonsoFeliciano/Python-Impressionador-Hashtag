# %% [markdown]
# # Filtrando informações nos dataframes
#
#
# ## Resumo
#
# Um dos grandes potenciais do pandas é para tratar condições.
#
# E a forma com que analisamos condições no dataframe é diferente do que já fizemos até agora no curso, vamos ver como funciona.

# %% [markdown]
# - Preparando as bases de dados

# %%
import pandas as pd
#importando os arquivos
#importando os arquivos
vendas_df = pd.read_csv(r'files/Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'files/Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'files/Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'files/Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome da Marca']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0              981            2        6825                   9
# 1              235           10        6825                   8
# 2              376            2        6825                   9
# 3              448            2        6825                  48
# 4              280            1        6825                  10
# ...            ...          ...         ...                 ...
# 980637         889            4         347                  12
# 980638        1367            5       38781                  13
# 980639         269            1         553                  10
# 980640         809            4       38860                   6
# 980641        1435           10         815                   8
#
#         Quantidade Devolvida         Nome da Marca  \
# 0                          1              A. Datum
# 1                          0               Litware
# 2                          0       Adventure Works
# 3                          0  Wide World Importers
# 4                          0               Contoso
# ...                      ...                   ...
# 980637                     1               Contoso
# 980638                     0               Contoso
# 980639                     0               Contoso
# 980640                     0               Contoso
# 980641                     0     The Phone Company
#
#                        Nome da Loja            E-mail do Cliente
# 0              Loja Contoso Austin        rbrumfieldmy@ameblo.jp
# 1       Loja Contoso Europe Online        rbrumfieldmy@ameblo.jp
# 2            Loja Contoso Hartford        rbrumfieldmy@ameblo.jp
# 3             Loja Contoso Catalog        rbrumfieldmy@ameblo.jp
# 4       Loja Contoso Beaumont No.1        rbrumfieldmy@ameblo.jp
# ...                             ...                          ...
# 980637        Loja Contoso Orlando            edowner9m@imdb.com
# 980638  Loja Contoso Damascus No.1   ruben31@adventure-works.com
# 980639  Loja Contoso New York No.1    akuhnertfc@themeforest.net
# 980640  Loja Contoso New York No.1     anne5@adventure-works.com
# 980641           Loja Contoso Roma      ekorneevmm@instagram.com
#
# [980642 rows x 13 columns]

# %% [markdown]
# ### Primeiro, vamos aplicar uma função normalmente. Qual o % das vendas que foi devolvido?
#
# - Para isso vamos somar as quantidades nas colunas correspondentes. Lembrando, o % vai ser: Total Devolvido / Total Vendido.

# %%
quantidade_vendida = vendas_df['Quantidade Vendida'].sum()
quantidade_devolvida = vendas_df['Quantidade Devolvida'].sum()

print('O percentual foi de: {:.2%}'.format(quantidade_devolvida/quantidade_vendida))
# Out:
# O percentual foi de: 1.17%

# %% [markdown]
# ### Agora, se quisermos fazer a mesma análise apenas para 1 loja. Queremos filtrar apenas os itens da Loja Contoso Europe Online e saber o % de devolução dessa loja.
#
# - Para isso, vamos precisar filtrar. A forma de filtrar nos dataframes é uma "simples" comparação

# %%
#Filtrando a loja
vendas_loja_contoso = vendas_df[vendas_df['ID Loja'] == 306]

#Calculando as quantidades
quantidade_vendida = vendas_loja_contoso['Quantidade Vendida'].sum()
quantidade_devolvida = vendas_loja_contoso['Quantidade Devolvida'].sum()

print('O percentual foi de: {:.2%}'.format(quantidade_devolvida/quantidade_vendida))
# Out:
# O percentual foi de: 1.33%

# %% [markdown]
# ### Vamos fazer em 2 passos para entender certinho o que está acontecendo.

# %%
#vendas_loja_contoso = vendas_df[vendas_df['ID Loja'] == 306]
loja_306 = vendas_df['ID Loja'] == 306
vendas_loja_contoso = vendas_df[loja_306]

display(vendas_loja_contoso)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 1                880458    23/11/2017    23/11/2017         0      306
# 17               614980    18/08/2017    18/08/2017         0      306
# 18               786402    21/10/2017    25/10/2017         4      306
# 19               383897    25/05/2017    28/05/2017         3      306
# 77               559478    26/07/2017    29/07/2017         3      306
# ...                 ...           ...           ...       ...      ...
# 885329           865745    18/11/2017    24/11/2017         6      306
# 885356           907944    04/12/2017    04/12/2017         0      306
# 885386           919123    08/12/2017    08/12/2017         0      306
# 885390           964452    25/12/2017    25/12/2017         0      306
# 885415           900861    01/12/2017    05/12/2017         4      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 1              235           10        6825                   8
# 17            1621            9       21344                   4
# 18             226           10       21344                   8
# 19             347            1       21344                  20
# 77            1382            1       24440                   5
# ...            ...          ...         ...                 ...
# 885329         823           10        9259                   8
# 885356         208           10       18529                   8
# 885386         208           10       38811                   8
# 885390         192           10       30633                   8
# 885415         224           10        8596                   8
#
#         Quantidade Devolvida Nome da Marca                 Nome da Loja  \
# 1                          0       Litware  Loja Contoso Europe Online
# 17                         0       Contoso  Loja Contoso Europe Online
# 18                         0       Litware  Loja Contoso Europe Online
# 19                         0      Fabrikam  Loja Contoso Europe Online
# 77                         0       Contoso  Loja Contoso Europe Online
# ...                      ...           ...                          ...
# 885329                     0       Contoso  Loja Contoso Europe Online
# 885356                     0       Litware  Loja Contoso Europe Online
# 885386                     0       Litware  Loja Contoso Europe Online
# 885390                     0       Litware  Loja Contoso Europe Online
# 885415                     0       Litware  Loja Contoso Europe Online
#
#                      E-mail do Cliente
# 1               rbrumfieldmy@ameblo.jp
# 17        makayla3@adventure-works.com
# 18        makayla3@adventure-works.com
# 19        makayla3@adventure-works.com
# 77          noah55@adventure-works.com
# ...                                ...
# 885329        mplaskitt78@marriott.com
# 885356           eribchesteres@pbs.org
# 885386   jessica47@adventure-works.com
# 885390  terrence23@adventure-works.com
# 885415           cmordangl@webnode.com
#
# [42771 rows x 13 columns]

# %% [markdown]
# ### Desafio: e se eu quisesse criar uma tabela apenas com as vendas da Loja Contoso Europe Online e que não tiveram nenhuma devolução. Quero criar essa tabela e saber quantas vendas são.
#
# - Repare que nesse caso são 2 condições, como fazemos isso?

# %%
#tudo junto
df_loja_306_sem_devolucao = vendas_df[(vendas_df['ID Loja'] == 306) & (vendas_df['Quantidade Devolvida'] == 0)]
display(df_loja_306_sem_devolucao)

#separado
loja_306 = vendas_df['ID Loja'] == 306
quantidade_devolvida_zero = vendas_df['Quantidade Devolvida'] == 0
df2_loja_306_sem_devolucao = vendas_df[loja_306 & quantidade_devolvida_zero]
display(df2_loja_306_sem_devolucao)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 1                880458    23/11/2017    23/11/2017         0      306
# 17               614980    18/08/2017    18/08/2017         0      306
# 18               786402    21/10/2017    25/10/2017         4      306
# 19               383897    25/05/2017    28/05/2017         3      306
# 77               559478    26/07/2017    29/07/2017         3      306
# ...                 ...           ...           ...       ...      ...
# 885329           865745    18/11/2017    24/11/2017         6      306
# 885356           907944    04/12/2017    04/12/2017         0      306
# 885386           919123    08/12/2017    08/12/2017         0      306
# 885390           964452    25/12/2017    25/12/2017         0      306
# 885415           900861    01/12/2017    05/12/2017         4      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 1              235           10        6825                   8
# 17            1621            9       21344                   4
# 18             226           10       21344                   8
# 19             347            1       21344                  20
# 77            1382            1       24440                   5
# ...            ...          ...         ...                 ...
# 885329         823           10        9259                   8
# 885356         208           10       18529                   8
# 885386         208           10       38811                   8
# 885390         192           10       30633                   8
# 885415         224           10        8596                   8
#
#         Quantidade Devolvida Nome da Marca                 Nome da Loja  \
# 1                          0       Litware  Loja Contoso Europe Online
# 17                         0       Contoso  Loja Contoso Europe Online
# 18                         0       Litware  Loja Contoso Europe Online
# 19                         0      Fabrikam  Loja Contoso Europe Online
# 77                         0       Contoso  Loja Contoso Europe Online
# ...                      ...           ...                          ...
# 885329                     0       Contoso  Loja Contoso Europe Online
# 885356                     0       Litware  Loja Contoso Europe Online
# 885386                     0       Litware  Loja Contoso Europe Online
# 885390                     0       Litware  Loja Contoso Europe Online
# 885415                     0       Litware  Loja Contoso Europe Online
#
#                      E-mail do Cliente
# 1               rbrumfieldmy@ameblo.jp
# 17        makayla3@adventure-works.com
# 18        makayla3@adventure-works.com
# 19        makayla3@adventure-works.com
# 77          noah55@adventure-works.com
# ...                                ...
# 885329        mplaskitt78@marriott.com
# 885356           eribchesteres@pbs.org
# 885386   jessica47@adventure-works.com
# 885390  terrence23@adventure-works.com
# 885415           cmordangl@webnode.com
#
# [35029 rows x 13 columns]
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 1                880458    23/11/2017    23/11/2017         0      306
# 17               614980    18/08/2017    18/08/2017         0      306
# 18               786402    21/10/2017    25/10/2017         4      306
# 19               383897    25/05/2017    28/05/2017         3      306
# 77               559478    26/07/2017    29/07/2017         3      306
# ...                 ...           ...           ...       ...      ...
# 885329           865745    18/11/2017    24/11/2017         6      306
# 885356           907944    04/12/2017    04/12/2017         0      306
# 885386           919123    08/12/2017    08/12/2017         0      306
# 885390           964452    25/12/2017    25/12/2017         0      306
# 885415           900861    01/12/2017    05/12/2017         4      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 1              235           10        6825                   8
# 17            1621            9       21344                   4
# 18             226           10       21344                   8
# 19             347            1       21344                  20
# 77            1382            1       24440                   5
# ...            ...          ...         ...                 ...
# 885329         823           10        9259                   8
# 885356         208           10       18529                   8
# 885386         208           10       38811                   8
# 885390         192           10       30633                   8
# 885415         224           10        8596                   8
#
#         Quantidade Devolvida Nome da Marca                 Nome da Loja  \
# 1                          0       Litware  Loja Contoso Europe Online
# 17                         0       Contoso  Loja Contoso Europe Online
# 18                         0       Litware  Loja Contoso Europe Online
# 19                         0      Fabrikam  Loja Contoso Europe Online
# 77                         0       Contoso  Loja Contoso Europe Online
# ...                      ...           ...                          ...
# 885329                     0       Contoso  Loja Contoso Europe Online
# 885356                     0       Litware  Loja Contoso Europe Online
# 885386                     0       Litware  Loja Contoso Europe Online
# 885390                     0       Litware  Loja Contoso Europe Online
# 885415                     0       Litware  Loja Contoso Europe Online
#
#                      E-mail do Cliente
# 1               rbrumfieldmy@ameblo.jp
# 17        makayla3@adventure-works.com
# 18        makayla3@adventure-works.com
# 19        makayla3@adventure-works.com
# 77          noah55@adventure-works.com
# ...                                ...
# 885329        mplaskitt78@marriott.com
# 885356           eribchesteres@pbs.org
# 885386   jessica47@adventure-works.com
# 885390  terrence23@adventure-works.com
# 885415           cmordangl@webnode.com
#
# [35029 rows x 13 columns]
